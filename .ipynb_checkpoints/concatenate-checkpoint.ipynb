# %%
# dependencies
import pandas as pd

# %%
#pull in csv data
january_csv = "Data/january21-citibike-tripdata.csv"
february_csv = "Data/february21-citibike-tripdata.csv"
march_csv = "Data/march21-citibike-tripdata.csv"

# %%
#create data frames
january_df = pd.read_csv(january_csv)
february_df = pd.read_csv(february_csv)
march_df = pd.read_csv(march_csv)

# %%
# concatenate data frames together
data_frames = [january_df, february_df, march_df]
data = pd.concat(data_frames)
data
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               266  2021-01-01 00:03:35.5100  2021-01-01 00:08:01.7770
# 1              1543  2021-01-01 00:23:32.9250  2021-01-01 00:49:16.0830
# 2              1461  2021-01-01 00:23:50.7940  2021-01-01 00:48:12.5660
# 3               793  2021-01-01 00:31:09.0770  2021-01-01 00:44:22.9430
# 4               596  2021-01-01 00:35:52.1900  2021-01-01 00:45:48.7740
# ...             ...                       ...                       ...
# 16838           493  2021-03-31 23:49:04.6750  2021-03-31 23:57:17.7900
# 16839           296  2021-03-31 23:49:33.7240  2021-03-31 23:54:29.8450
# 16840           346  2021-03-31 23:53:36.2020  2021-03-31 23:59:22.2370
# 16841           872  2021-03-31 23:54:36.3950  2021-04-01 00:09:09.1080
# 16842           587  2021-03-31 23:58:04.5740  2021-04-01 00:07:52.2170
#
#        start station id     start station name  start station latitude  \
# ...

# %%
#export new data frame as CSV
data.to_csv("data.csv", index = False, header=True)
